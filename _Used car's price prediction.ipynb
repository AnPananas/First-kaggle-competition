# %% [markdown]
# # Used car's price prediction

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-задачи" data-toc-modified-id="Описание-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Описание задачи</a></span></li><li><span><a href="#Метрика-качества" data-toc-modified-id="Метрика-качества-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Метрика качества</a></span></li><li><span><a href="#Данные" data-toc-modified-id="Данные-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Данные</a></span></li><li><span><a href="#Описание--данных" data-toc-modified-id="Описание--данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Описание  данных</a></span></li><li><span><a href="#Импорт-библиотек" data-toc-modified-id="Импорт-библиотек-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Импорт библиотек</a></span></li><li><span><a href="#Загрузка-и-ознакомление-с-данными" data-toc-modified-id="Загрузка-и-ознакомление-с-данными-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Загрузка и ознакомление с данными</a></span></li><li><span><a href="#Предварительная-обработка" data-toc-modified-id="Предварительная-обработка-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Предварительная обработка</a></span><ul class="toc-item"><li><span><a href="#Заменим-неявные-дубликаты" data-toc-modified-id="Заменим-неявные-дубликаты-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Заменим неявные дубликаты</a></span></li><li><span><a href="#используя-первые-8-символов-вина-учтоняем-модели" data-toc-modified-id="используя-первые-8-символов-вина-учтоняем-модели-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>используя первые 8 символов вина учтоняем модели</a></span></li><li><span><a href="#создадим-отдельные-столбцы-с-первыми-тремя-(указывают-на-производителя)-и-первыми-8-ю-символами-вин-номера-(указывают-на-модель-и-модификацию)" data-toc-modified-id="создадим-отдельные-столбцы-с-первыми-тремя-(указывают-на-производителя)-и-первыми-8-ю-символами-вин-номера-(указывают-на-модель-и-модификацию)-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>создадим отдельные столбцы с первыми тремя (указывают на производителя) и первыми 8-ю символами вин-номера (указывают на модель и модификацию)</a></span></li></ul></li><li><span><a href="#полноценный-разведочный-анализ-(EDA)" data-toc-modified-id="полноценный-разведочный-анализ-(EDA)-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>полноценный разведочный анализ (EDA)</a></span><ul class="toc-item"><li><span><a href="#визуализируем-полученные-данные" data-toc-modified-id="визуализируем-полученные-данные-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>визуализируем полученные данные</a></span></li></ul></li><li><span><a href="#отбор-финального-набора-обучающих-признаков" data-toc-modified-id="отбор-финального-набора-обучающих-признаков-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>отбор финального набора обучающих признаков</a></span></li><li><span><a href="#обучение-модели" data-toc-modified-id="обучение-модели-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>обучение модели</a></span></li><li><span><a href="#Aнализ-важности--признаков" data-toc-modified-id="Aнализ-важности--признаков-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Aнализ важности  признаков</a></span></li></ul></div>

# %% [markdown]
# ## Описание проекта
#
# - Многие знают про маркетплейсы где продаются б/у вещи, на которых есть возможность недорого купить качественную и полезную вещь. Но всегда волнует вопрос - кто и как устанавливает цену, и какие его характеристики больше всего влияют на итоговую стоимость продажи?! Вопрос становиться особо актуальным, если речь идет про дорогие товары, например про автомобили!

# %% [markdown]
# ## Описание задачи
# - Целью  проекта будет разработанная модель предсказания стоимости автомобиля на вторичном рынке.

# %% [markdown]
# ## Метрика качества
#
# - Работа  модели будет оцениваться по метрике MAPE (Mean Absolute Percentage Error)

# %% [markdown]
# ## Данные
# - train.csv - информация о продажах (~440000) автомобилей с аукционов, которые будут использоваться в качестве обучающих данных.
# - test.csv - информация о продажах (~110000) автомобилей с аукционов, которые будут использоваться в качестве тестовых данных.
#
# - vin - идентификатор каждого автомобиля в тестовом наборе.
# - sellingprice - Целевой признак. Для каждого автомобиля предскажите числовое значение стоимости автомобиля.

# %% [markdown]
# ## Описание  данных
# - 'year' - год производства
# - 'make' - производитель
# - 'model' - модель
# - 'trim' - модификация
# - 'body' - тип кузова
# - 'transmission' - тип КПП
# - 'vin' - идентификатор (вин)
# - 'state' - штат регистрации
# - 'condition' - состояние по шкале (1-5)
# - 'odometer' - пробег в милях
# - 'color' - цвет кузова
# - 'interior' - цвет интерьера
# - 'seller' - продавец
# - 'sellingprice' - стоимость продажи
# - 'saledate' - дата продажи

# %% [markdown]
# ## Импорт библиотек

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
#!pip install catboost
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
from datetime import datetime
import re
import seaborn as sns
from catboost import CatBoostRegressor,CatBoost
from catboost import Pool, cv
from sklearn.model_selection import train_test_split,GridSearchCV #  для разбиения выборки
from sklearn.preprocessing import OrdinalEncoder,OneHotEncoder, StandardScaler # для прямого кодирования имасштабирования признаков
from sklearn.linear_model import LogisticRegression # для созданиия модели логистической регрессии
from sklearn.tree import DecisionTreeClassifier # для созданиия модели дерева решений
from sklearn.ensemble import RandomForestClassifier # для созданиия модели случайного леса
from sklearn.metrics import  roc_auc_score, roc_curve,make_scorer, recall_score # для постороения ROC кривой и подсчета метрики AUC
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import mean_absolute_percentage_error
pd.set_option('display.max_columns', None) # для отображения  всех столбцов
sns.set_theme(style="whitegrid")
from pandas.api.types import is_numeric_dtype
from sklearn.metrics import classification_report
from sklearn.metrics import mean_squared_error
#import optuna
import catboost
from catboost import Pool

#!pip install scikit-optimize
from skopt import BayesSearchCV
from skopt.space import Real, Integer
from sklearn.metrics import make_scorer
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

#import os
#for dirname, _, filenames in os.walk('/kaggle/input'):
  #  for filename in filenames:
  #      print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# ## Загрузка и ознакомление с данными

# %%
# Выгружаем данные
train = pd.read_csv('D:/yandex_practicum/Projects/kaggle_cars/train.csv')
test = pd.read_csv('D:/yandex_practicum/Projects/kaggle_cars/test.csv')
train
# Out:
#         year    make              model       trim      body transmission  \
# 0       2011    Ford               Edge        SEL       suv    automatic
# 1       2014    Ford             Fusion         SE     Sedan    automatic
# 2       2012  Nissan             Sentra     2.0 SL     sedan    automatic
# 3       2003  HUMMER                 H2       Base       suv    automatic
# 4       2007    Ford             Fusion        SEL     Sedan    automatic
# ...      ...     ...                ...        ...       ...          ...
# 440231  2013     Kia             Optima  EX Hybrid     Sedan    automatic
# 440232  2014    MINI  Cooper Countryman     S ALL4     Wagon    automatic
# 440233  2008     BMW           6 Series       650i     Coupe    automatic
# 440234  2014     Ram               2500        SLT  Crew Cab    automatic
# 440235  2013  Nissan              Rogue         SV       SUV    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440236 entries, 0 to 440235
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          440236 non-null  int64
#  1   make          432193 non-null  object
#  2   model         432113 non-null  object
#  3   trim          431899 non-null  object
#  4   body          429843 non-null  object
#  5   transmission  388775 non-null  object
#  6   vin           440236 non-null  object
#  7   state         440236 non-null  object
#  8   condition     430831 non-null  float64
#  9   odometer      440167 non-null  float64
#  10  color         439650 non-null  object
#  11  interior      439650 non-null  object
#  12  seller        440236 non-null  object
#  13  sellingprice  440236 non-null  int64
#  14  saledate      440236 non-null  object
# dtypes: float64(2), int64(2), object(11)
# memory usage: 50.4+ MB

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         1.826975
# model                model         1.845147
# trim                  trim         1.893757
# body                  body         2.360779
# transmission  transmission        11.689412
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.136354
# odometer          odometer         0.015673
# color                color         0.133110
# interior          interior         0.133110
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000

# %% [markdown]
# Имеем пропуски в следующих категориалных столбцах:
#
# - [x] make
# - [x] model
# - [x] trim
# - [x] body
# - [x] transmission
# - [x] color
# - [x] interior
#
# Имеем пропуски в следующих числовых столбцах:
#
# - [x] condition
# - [x] odometer

# %% [markdown]
# В следующих столбцах неправильный тип данных:
#
# - [x] saledate (должен быть datetime)

# %% [markdown]
# ## Предварительная обработка

# %%
str_col =['vin','make', 'model', 'trim', 'body', 'transmission',  'state',
         'color', 'interior', 'seller']

# %%
train.vin.duplicated().sum()
# Out:
# 0

# %%
def low(col):
    return col.str.lower()
train[str_col] = train[str_col].apply(low)
test[str_col] = test[str_col].apply(low)

# %%
train.vin.duplicated().sum()
# Out:
# 0

# %%
train.make.value_counts().head()
test.make.value_counts().head()
# Out:
# ford         18465
# chevrolet    11801
# nissan       10485
# toyota        7728
# dodge         6188
# Name: make, dtype: int64

# %%
train.make.value_counts().tail(60)
test.make.value_counts().tail(60)
# Out:
# ford             18465
# chevrolet        11801
# nissan           10485
# toyota            7728
# dodge             6188
# honda             5382
# hyundai           4409
# bmw               4136
# kia               3571
# mercedes-benz     3463
# chrysler          3459
# jeep              3069
# infiniti          3002
# volkswagen        2509
# lexus             2430
# gmc               2059
# mazda             1676
# cadillac          1496
# lincoln           1153
# acura             1151
# audi              1124
# buick             1019
# subaru            1015
# ram                889
# pontiac            866
# mitsubishi         806
# volvo              765
# mini               674
# saturn             544
# mercury            434
# land rover         363
# scion              318
# jaguar             297
# porsche            280
# suzuki             222
# fiat               181
# hummer             174
# saab                93
# oldsmobile          88
# smart               81
# ...

# %% [markdown]
# vw = volkswagen
#
# mercedes-b = mercedes  = mercedes-benz
#
# ford truck = ford
#
# truck gmc = gmc
#
# dodge tk = dodge
#
# mazda tk = mazda
# land rover   = landrover

# %% [markdown]
# ### Заменим неявные дубликаты

# %%
train.loc[train['make'].str.contains('mercedes') == True,'make'] = 'mercedes'
train.loc[train['make'].str.contains('ford') == True,'make'] = 'ford'
train.loc[train['make'].str.contains('gmc') == True,'make'] = 'gmc'
train.loc[train['make'].str.contains('dodge') == True,'make'] = 'dodge'
train.loc[train['make'].str.contains('mazda') == True,'make'] = 'mazda'
train.loc[train['make'].str.contains('vw') == True,'make'] = 'volkswagen'
train.loc[train['make'].str.contains('land') == True,'make'] = 'land rover'


test.loc[test['make'].str.contains('mercedes') == True,'make'] = 'mercedes'
test.loc[test['make'].str.contains('ford') == True,'make'] = 'ford'
test.loc[test['make'].str.contains('gmc') == True,'make'] = 'gmc'
test.loc[test['make'].str.contains('dodge') == True,'make'] = 'dodge'
test.loc[test['make'].str.contains('mazda') == True,'make'] = 'mazda'
test.loc[test['make'].str.contains('vw') == True,'make'] = 'volkswagen'
test.loc[test['make'].str.contains('land') == True,'make'] = 'land rover'
test.loc[test['make'].str.contains('hyundai') == True,'make'] = 'hyundai'

# %%
train
# Out:
#         year    make              model       trim      body transmission  \
# 0       2011    ford               edge        sel       suv    automatic
# 1       2014    ford             fusion         se     sedan    automatic
# 2       2012  nissan             sentra     2.0 sl     sedan    automatic
# 3       2003  hummer                 h2       base       suv    automatic
# 4       2007    ford             fusion        sel     sedan    automatic
# ...      ...     ...                ...        ...       ...          ...
# 440231  2013     kia             optima  ex hybrid     sedan    automatic
# 440232  2014    mini  cooper countryman     s all4     wagon    automatic
# 440233  2008     bmw           6 series       650i     coupe    automatic
# 440234  2014     ram               2500        slt  crew cab    automatic
# 440235  2013  nissan              rogue         sv       suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
train[train['make'].str.contains('mercedes')==True]
# Out:
#         year      make      model               trim         body  \
# 31      2012  mercedes   gl-class       gl450 4matic          suv
# 73      2013  mercedes    e-class  e350 sport 4matic        sedan
# 89      1999  mercedes     e300dt                NaN          NaN
# 134     2013  mercedes   sl-class              sl550  convertible
# 279     2006  mercedes    r-class               r350        wagon
# ...      ...       ...        ...                ...          ...
# 440060  2001  mercedes    e-class               e320        wagon
# 440127  2014  mercedes  glk-class             glk350          suv
# 440173  2013  mercedes  cls-class      cls550 4matic        sedan
# 440178  2011  mercedes  glk-class             glk350          suv
# 440230  2011  mercedes    e-class               e350        sedan
#
#        transmission                vin state  condition  odometer   color  \
# 31              NaN  4jgbf7be8ca797360    ga        4.1   55612.0   white
# ...

# %%
train[(train.make.isna()) ]
# Out:
#         year make model trim body transmission                vin state  \
# 10      2007  NaN   NaN  NaN  NaN    automatic  5tfbv54157x019560    ca
# 42      2007  NaN   NaN  NaN  NaN       manual  jm1bk34l671745431    md
# 63      2011  NaN   NaN  NaN  NaN    automatic  1fdne1bw5bda64735    ga
# 64      2008  NaN   NaN  NaN  NaN    automatic  1gbdv13wx8d142776    ca
# 111     2006  NaN   NaN  NaN  NaN    automatic  3gnda13d36s611801    nv
# ...      ...  ...   ...  ...  ...          ...                ...   ...
# 440085  2011  NaN   NaN  NaN  NaN    automatic  1fdne1bw8bdb21610    az
# 440114  2011  NaN   NaN  NaN  NaN    automatic  2lnbl8ev9bx757689    nj
# 440118  2004  NaN   NaN  NaN  NaN    automatic  1gyde637240130408    md
# 440122  2007  NaN   NaN  NaN  NaN    automatic  salme15487a251642    ca
# 440144  2004  NaN   NaN  NaN  NaN    automatic  2c4gm68474r511987    oh
#
#         condition  odometer   color interior  \
# 10            3.1  102507.0    blue     gray
# ...

# %% [markdown]
# Около 2% пропусков в колонке make.
# Не будем пока с ними ничего делать, заполнить не имеется возможности

# %%
train.duplicated().sum()
test.duplicated().sum()
# Out:
# 0

# %%
train.loc[train['model'].str.contains('f150') == True]['make'].unique()
# Out:
# array(['ford'], dtype=object)

# %%
# Заменим неявные дубликаты
train.loc[train['model'].str.contains('allroad') == True,'model'] = 'allroad quattro'
train.loc[train['model'].str.contains('flying spur') == True,'model'] = 'continental flying spur'
train.loc[train['model'].str.contains('cts wagon') == True,'model'] = 'cts-v wagon'
train.loc[(train['model'].str.contains('grand') == True) & (train['make'] == 'dodge'),'model'] = 'gr'
train.loc[(train['model'].str.contains('gr') == True) & (train['make'] == 'dodge'),'model'] = 'grand caravan'
train.loc[train['model'].str.contains('expedit') == True,'model'] = 'expedition'
train.loc[(train['model'].str.contains('1500') == True) & (train['make'] == 'gmc'),'model'] = 'sierra 1500'
train.loc[(train['model'].str.contains('2500') == True) & (train['make'] == 'gmc'),'model'] = 'sierra 2500'

train.loc[train['model'].str.contains('siera') == True,'model'] = 'sr'
train.loc[(train['model'].str.contains('sr') == True) & (train['make'] == 'gmc'),'model'] = 'sierra'
train.loc[train['model'].str.contains('subrb') == True,'model'] = 'suburban'
train.loc[train['model'].str.contains('santa') == True,'model'] = 'santa fe'
train.loc[train['model'].str.contains('xj') == True,'model'] = 'xj'
train.loc[train['model'].str.contains('xk') == True,'model'] = 'xk'
train.loc[(train['model'].str.contains('grand') == True) & (train['make'] == 'jeep'),'model'] = 'gr'
train.loc[(train['model'].str.contains('gr') == True) & (train['make'] == 'jeep'),'model'] = 'grand cherokee'

train.loc[(train['model'].str.contains('range rover evoque') == True) & (train['make'] == 'land rover'),'model'] = 'rre'
train.loc[(train['model'].str.contains('range rover sport') == True) & (train['make'] == 'land rover'),'model'] = 'rrs'
train.loc[(train['model'].str.contains('range') == True) & (train['make'] == 'land rover'),'model'] = 'rr'
train.loc[(train['model'].str.contains('rre') == True) & (train['make'] == 'land rover'),'model'] = 'range rover evoque'
train.loc[(train['model'].str.contains('rrs') == True) & (train['make'] == 'land rover'),'model'] = 'range rover sport'
train.loc[(train['model'].str.contains('rr') == True) & (train['make'] == 'land rover'),'model'] = 'range rover'

train.loc[train['model'].str.contains('mazda3') == True,'model'] = '3'
train.loc[train['model'].str.contains('mazda6') == True,'model'] = '6'
train.loc[(train['model'].str.contains('rx') == True) & (train['make'] == 'mazda'),'model'] = 'rx8'
train.loc[train['model'].str.contains('mazdaspeed mazda3') == True,'model'] = 'mazdaspeed3'
train.loc[train['model'].str.contains('mazdaspeed3') == True,'model'] = 'mazdaspeed 3'
train.loc[train['model'].str.contains('mount') == True,'model'] = 'mountaineer'
train.loc[train['model'].str.contains('pathfind') == True,'model'] = 'pathfinder'
train.loc[train['model'].str.contains('tradesman') == True,'model'] = 'cv tradesman'
train.loc[train['model'].str.contains('tribeca') == True,'model'] = 'tribeca'

train.loc[(train['model'].str.contains('grand') == True) & (train['make'] == 'suzuki'),'model'] = 'grand vitara'

train.loc[train['model'].str.contains('f150') == True,'model'] = 'f-150'
train.loc[train['model'].str.contains('f250') == True,'model'] = 'f-250'
train.loc[train['model'].str.contains('e150') == True,'model'] = 'e-150'
train.loc[train['model'].str.contains('e250') == True,'model'] = 'e-250'
train.loc[train['model'].str.contains('e350') == True,'model'] = 'e-350'



test.loc[test['model'].str.contains('allroad') == True,'model'] = 'allroad quattro'
test.loc[test['model'].str.contains('flying spur') == True,'model'] = 'continental flying spur'
test.loc[test['model'].str.contains('cts wagon') == True,'model'] = 'cts-v wagon'
test.loc[(test['model'].str.contains('grand') == True) & (test['make'] == 'dodge'),'model'] = 'gr'
test.loc[(test['model'].str.contains('gr') == True) & (test['make'] == 'dodge'),'model'] = 'grand caravan'
test.loc[test['model'].str.contains('expedit') == True,'model'] = 'expedition'
test.loc[(test['model'].str.contains('1500') == True) & (test['make'] == 'gmc'),'model'] = 'sierra 1500'
test.loc[(test['model'].str.contains('2500') == True) & (test['make'] == 'gmc'),'model'] = 'sierra 2500'

test.loc[test['model'].str.contains('siera') == True,'model'] = 'sr'
test.loc[(test['model'].str.contains('sr') == True) & (test['make'] == 'gmc'),'model'] = 'sierra'
test.loc[test['model'].str.contains('subrb') == True,'model'] = 'suburban'
test.loc[test['model'].str.contains('santa') == True,'model'] = 'santa fe'
test.loc[test['model'].str.contains('xj') == True,'model'] = 'xj'
test.loc[test['model'].str.contains('xk') == True,'model'] = 'xk'
test.loc[(test['model'].str.contains('grand') == True) & (test['make'] == 'jeep'),'model'] = 'gr'
test.loc[(test['model'].str.contains('gr') == True) & (test['make'] == 'jeep'),'model'] = 'grand cherokee'

test.loc[(test['model'].str.contains('range rover evoque') == True) & (test['make'] == 'land rover'),'model'] = 'rre'
test.loc[(test['model'].str.contains('range rover sport') == True) & (test['make'] == 'land rover'),'model'] = 'rrs'
test.loc[(test['model'].str.contains('range') == True) & (test['make'] == 'land rover'),'model'] = 'rr'
test.loc[(test['model'].str.contains('rre') == True) & (test['make'] == 'land rover'),'model'] = 'range rover evoque'
test.loc[(test['model'].str.contains('rrs') == True) & (test['make'] == 'land rover'),'model'] = 'range rover sport'
test.loc[(test['model'].str.contains('rr') == True) & (test['make'] == 'land rover'),'model'] = 'range rover'

test.loc[test['model'].str.contains('mazda3') == True,'model'] = '3'
test.loc[test['model'].str.contains('mazda6') == True,'model'] = '6'
test.loc[(test['model'].str.contains('rx') == True) & (test['make'] == 'mazda'),'model'] = 'rx8'
test.loc[test['model'].str.contains('mazdaspeed mazda3') == True,'model'] = 'mazdaspeed3'
test.loc[test['model'].str.contains('mazdaspeed3') == True,'model'] = 'mazdaspeed 3'
test.loc[test['model'].str.contains('mount') == True,'model'] = 'mountaineer'
test.loc[test['model'].str.contains('pathfind') == True,'model'] = 'pathfinder'
test.loc[test['model'].str.contains('tradesman') == True,'model'] = 'cv tradesman'
test.loc[test['model'].str.contains('tribeca') == True,'model'] = 'tribeca'

test.loc[(test['model'].str.contains('grand') == True) & (train['make'] == 'suzuki'),'model'] = 'grand vitara'

test.loc[test['model'].str.contains('f150') == True,'model'] = 'f-150'
test.loc[test['model'].str.contains('f250') == True,'model'] = 'f-250'
test.loc[test['model'].str.contains('e150') == True,'model'] = 'e-150'
test.loc[test['model'].str.contains('e250') == True,'model'] = 'e-250'
test.loc[test['model'].str.contains('e350') == True,'model'] = 'e-350'

# %%
#pd.set_option('display.max_rows', None)

train.groupby('make')['model'].agg('value_counts')
test.groupby('make')['model'].agg('value_counts')
# Out:
# make   model
# acura  tl       407
#        mdx      299
#        tsx      223
#        rdx       89
#        rsx       32
#                ...
# volvo  c30       11
#        850        4
#        v40        4
#        xc         3
#        s90        1
# Name: model, Length: 734, dtype: int64

# %%
# смотрим пропуски в колонке model
train[(~train.make.isna()) & (train.model.isna()) & (train.make == 'bmw')]
test[(~test.make.isna()) & (test.model.isna()) & (test.make == 'bmw')]
# Out:
#         year make model          trim   body transmission                vin  \
# 6617    2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c51ed142085
# 29811   2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c54ed653404
# 35939   2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c58ed653342
# 37790   2015  bmw   NaN   650i xdrive  sedan    automatic  wba6b4c57fd760847
# 42299   2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c54ed653421
# 42887   2015  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c51fd654253
# 49905   2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c52ed141950
# 51346   2014  bmw   NaN         750li  sedan    automatic  wbaye8c53ed134945
# 66584   2014  bmw   NaN         750li  sedan    automatic  wbaye8c58ed135282
# 71350   2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c55ed653556
# 72517   2014  bmw   NaN  750li xdrive  sedan    automatic  wbayf8c5xed653424
# ...

# %%
# функция для заполнения неаявных дубликатов
def name_model(row):
    #row = row['trim']
    if '750li' in row:
        return "750li"
    elif '750i'in row:
        return "750i"
    elif '650i'in row:
        return '650i'
    else:
        pass

train.loc[(~train.make.isna()) & (train.model.isna()) & (train.make == 'bmw'),'model'] = train.loc[(~train.make.isna())\
                                                                                                   & (train.model.isna())\
                                                                                                   & (train.make == 'bmw')]['trim'].apply(name_model)
train.loc[(train.make == 'bmw')]
test.loc[(~test.make.isna()) & (test.model.isna()) & (test.make == 'bmw'),'model'] = test.loc[(~test.make.isna())\
                                                                                              & (test.model.isna())\
                                                                                              & (test.make == 'bmw')]['trim'].apply(name_model)

# %% [markdown]
# ### используя первые 8 символов вина учтоняем модели

# %%
train.loc[(train.vin.str.contains('waubfgff')) & (train.make == 'audi'),'model'] = 'a3'
test.loc[(test.vin.str.contains('waubfgff')) & (test.make == 'audi'),'model'] =  'a3'

# %%
train.loc[(train.model.isna()) & (train.vin.str.contains('jh4kb165')), 'model'] =  'rl'
test.loc[(test.model.isna()) & (test.vin.str.contains('jh4kb165')), 'model'] =  'rl'
train.loc[(train.trim.isna()) & (train.vin.str.contains('jh4kb165')), 'trim'] =  'base'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jh4kb165')), 'trim'] =  'base'

# %%
train.loc[(train.trim.isna()) & (train.vin.str.contains('2fabp7bv')), 'trim'] =  'street app'
test.loc[((test.trim.isna()) & test.vin.str.contains('2fabp7bv')), 'trim'] =  'street app'
train.loc[(train.trim.isna()) & (train.vin.str.contains('2fafp71w')), 'trim'] =  'base'
test.loc[((test.trim.isna()) & test.vin.str.contains('2fafp71w')), 'trim'] =  'base'
train.loc[(train.trim.isna()) & (train.vin.str.contains('1fbjs31h')), 'trim'] =  'base'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1fbjs31h')), 'trim'] =  'base'
 
train.loc[(train.trim.isna()) & (train.vin.str.contains('1fmcu931')), 'trim'] =  '4x4 v6 xlt'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1fmcu931')), 'trim'] =  '4x4 v6 xlt'

train.loc[(train.body.isna()) & (train.vin.str.contains('1fmcu931')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('1fmcu931')), 'body'] =  'suv'

# %%
train.loc[(train.trim.isna()) & (train.vin.str.contains('1hgcm668')), 'trim'] =  'ex v-6'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1hgcm668')), 'trim'] =  'ex v-6'

train.loc[(train.body.isna()) & (train.vin.str.contains('1hgcm668')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('1hgcm668')), 'body'] =  'sedan'

train.loc[(train.trim.isna()) & (train.vin.str.contains('2hkyf184')), 'trim'] =  'ex'
test.loc[(test.trim.isna()) & (test.vin.str.contains('2hkyf184')), 'trim'] =  'ex'

train.loc[(train.body.isna()) & (train.vin.str.contains('2hkyf184')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('2hkyf184')), 'body'] =  'suv'

train.loc[(train.trim.isna()) & (train.vin.str.contains('2hkrl186')), 'trim'] =  'ex'
test.loc[((test.trim.isna()) & test.vin.str.contains('2hkrl186')), 'trim'] =  'ex'

train.loc[(train.body.isna()) & (train.vin.str.contains('2hkyf184')), 'body'] =  'minivan'
test.loc[((test.body.isna()) & test.vin.str.contains('2hkyf184')), 'body'] =  'minivan'

# %%
train.loc[(train.body.isna()) & (train.vin.str.contains('2t1kr32e')), 'body'] =  'wagon'
test.loc[((test.body.isna()) & test.vin.str.contains('2t1kr32e')), 'body'] =  'wagon'
train.loc[(train.trim.isna()) & (train.vin.str.contains('2t1kr32e')), 'trim'] =  'base'
test.loc[((test.trim.isna()) & test.vin.str.contains('2t1kr32e')), 'trim'] =  'base'

train.loc[(train.trim.isna()) & (train.vin.str.contains('jtdbt4k3')), 'trim'] =  'fleet'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jtdbt4k3')), 'trim'] =  'fleet'

train.loc[(train.body.isna()) & (train.vin.str.contains('jtdbt4k3')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('jtdbt4k3')), 'body'] =  'sedan'

# %%
train.loc[(train.trim.isna()) & (train.make == 'bmw'), 'trim' ] = 'base'
train.loc[(train.trim.isna()) & (train.make == 'bmw'), 'body' ] = 'sedan'

# %%
train.loc[(train.trim.isna()) & (train.vin.str.contains('2b4fp25b')), 'trim'] =  '4c base'
test.loc[(test.trim.isna()) & (test.vin.str.contains('2b4fp25b')), 'trim'] =  '4c base'

train.loc[(train.body.isna()) & (train.vin.str.contains('2b4fp25b')), 'body'] =  'minivan'
test.loc[(test.body.isna()) & (test.vin.str.contains('2b4fp25b')), 'body'] =  'minivan'

# %%
train.loc[(train.trim.isna()) & (train.vin.str.contains('1b3ej46x')), 'trim'] =  'se'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1b3ej46x')), 'trim'] =  'se'

train.loc[(train.body.isna()) & (train.vin.str.contains('1b3ej46x')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('1b3ej46x')), 'body'] =  'sedan'

train.loc[(train.trim.isna()) & (train.vin.str.contains('1b3el36x')), 'trim'] =  '4c se'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1b3el36x')), 'trim'] =  '4c se'

train.loc[(train.transmission.isna()) & (train.vin.str.contains('1b3el36x')), 'transmission'] =  'automatic'
test.loc[(test.transmission.isna()) & (test.vin.str.contains('1b3el36x')), 'transmission'] =  'automatic'

train.loc[(train.body.isna()) & (train.vin.str.contains('1b3el36x')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('1b3el36x')), 'body'] =  'sedan'

# %%
train.loc[(train.trim.isna()) & (train.vin.str.contains('jn1az34d')), 'trim'] =  '4x2'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jn1az34d')), 'trim'] =  '4x2'



train.loc[(train.body.isna()) & (train.vin.str.contains('jn1az34d')), 'body'] =  'coupe'
test.loc[(test.body.isna()) & (test.vin.str.contains('jn1az34d')), 'body'] =  'coupe'

train.loc[(train.trim.isna()) & (train.vin.str.contains('jn1az34e')), 'trim'] =  'touring'
test.loc[((test.trim.isna()) & test.vin.str.contains('jn1az34e')), 'trim'] =  'touring'

train.loc[(train.trim.isna()) & (train.vin.str.contains('jn1bz34e')), 'trim'] =  'base'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jn1bz34e')), 'trim'] =  'base'

train.loc[(train.body.isna()) & (train.vin.str.contains('jn1bz34e')), 'body'] =  'coupe'
test.loc[((test.body.isna()) & test.vin.str.contains('jn1bz34e')), 'body'] =  'coupe'

train.loc[(train.trim.isna()) & (train.vin.str.contains('jn1bz34d')), 'trim'] =  'base'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jn1bz34d')), 'trim'] =  'base'

train.loc[(train.body.isna()) & (train.vin.str.contains('jn1bz34d')), 'body'] =  'coupe'
test.loc[(test.body.isna()) & (test.vin.str.contains('jn1bz34d')), 'body'] =  'coupe'

train.loc[(train.trim.isna()) & (train.vin.str.contains('3n1cn7ap')), 'trim'] =  '1.6 sv'
test.loc[((test.trim.isna()) & test.vin.str.contains('3n1cn7ap')), 'trim'] =  '1.6 sv'
train.loc[(train.body.isna()) & (train.vin.str.contains('3n1cn7ap')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('3n1cn7ap')), 'body'] =  'sedan'

train.loc[(train.trim.isna()) & (train.vin.str.contains('jn8ar07y')), 'trim'] =  'le'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jn8ar07y')), 'trim'] =  'le'
train.loc[(train.body.isna()) & (train.vin.str.contains('jn8ar07y')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('jn8ar07y')), 'body'] =  'suv'

train.loc[(train.trim.isna()) & (train.vin.str.contains('kl5tj666')), 'trim'] =  'AMT'
test.loc[((test.trim.isna()) & test.vin.str.contains('kl5tj666')), 'trim'] =  'AMT'
train.loc[(train.body.isna()) & (train.vin.str.contains('kl5tj666')), 'body'] =  'hatchback'
test.loc[(test.body.isna()) & (test.vin.str.contains('kl5tj666')), 'body'] =  'hatchback'

train.loc[(train.trim.isna()) & (train.vin.str.contains('kmhdt4bd')), 'trim'] =  'HD'
test.loc[(test.trim.isna()) & (test.vin.str.contains('kmhdt4bd')), 'trim'] =  'HD'
train.loc[(train.body.isna()) & (train.vin.str.contains('kmhdt4bd')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('kmhdt4bd')), 'body'] =  'sedan'

train.loc[(train.trim.isna()) & (train.vin.str.contains('1gyee637')), 'trim'] =  'v6'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1gyee637')), 'trim'] =  'v6'
train.loc[(train.body.isna()) & (train.vin.str.contains('1gyee637')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('1gyee637')), 'body'] =  'suv'

train.loc[(train.trim.isna()) & (train.vin.str.contains('zamfe39a')), 'trim'] =  'sport gt s automatic'
test.loc[(test.trim.isna()) & (test.vin.str.contains('zamfe39a')), 'trim'] =  'sport gt s automatic'
train.loc[(train.body.isna()) & (train.vin.str.contains('zamfe39a')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('zamfe39a')), 'body'] =  'sedan'

train.loc[(train.trim.isna()) & (train.vin.str.contains('wp0aa299')), 'trim'] =  'carrera'
test.loc[((test.trim.isna()) & test.vin.str.contains('wp0aa299')), 'trim'] =  'carrera'
train.loc[(train.body.isna()) & (train.vin.str.contains('wp0aa299')), 'body'] =  'coupe'
test.loc[(test.body.isna()) & (test.vin.str.contains('wp0aa299')), 'body'] =  'coupe'

train.loc[(train.trim.isna()) & (train.vin.str.contains('1j4fy19s')), 'trim'] =  'sport'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1j4fy19s')), 'trim'] =  'sport'
train.loc[(train.body.isna()) & (train.vin.str.contains('1j4fy19s')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('1j4fy19s')), 'body'] =  'suv'

train.loc[(train.trim.isna()) & (train.vin.str.contains('2c4rvabg')), 'trim'] =  'se'
test.loc[(test.trim.isna()) & (test.vin.str.contains('2c4rvabg')), 'trim'] =  'se'
train.loc[(train.body.isna()) & (train.vin.str.contains('2c4rvabg')), 'body'] =  'minivan'
test.loc[(test.body.isna()) & (test.vin.str.contains('2c4rvabg')), 'body'] =  'minivan'

train.loc[(train.trim.isna()) & (train.vin.str.contains('4a32b2ff')), 'trim'] =  'fe'
test.loc[(test.trim.isna()) & (test.vin.str.contains('4a32b2ff')), 'trim'] =  'fe'
train.loc[(train.body.isna()) & (train.vin.str.contains('4a32b2ff')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('4a32b2ff')), 'body'] =  'sedan'


train.loc[(train.trim.isna()) & (train.vin.str.contains('4m2xv11t')), 'trim'] =  'fwd estate'
test.loc[(test.trim.isna()) & (test.vin.str.contains('4m2xv11t')), 'trim'] =  'fwd estate'


train.loc[(train.trim.isna()) & (train.vin.str.contains('1b4hs28y')), 'trim'] =  'slt'
test.loc[(test.trim.isna()) & (test.vin.str.contains('1b4hs28y')), 'trim'] =  'slt'
train.loc[(train.body.isna()) & (train.vin.str.contains('1b4hs28y')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('1b4hs28y')), 'body'] =  'suv'



train.loc[(train.trim.isna()) & (train.vin.str.contains('wdbrf52h')), 'trim'] =  'c230 sport'
test.loc[(test.trim.isna()) & (test.vin.str.contains('wdbrf52h')), 'trim'] =  'c230 sport'
train.loc[(train.body.isna()) & (train.vin.str.contains('wdbrf52h')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('wdbrf52h')), 'body'] =  'sedan'


train.loc[(train.trim.isna()) & (train.vin.str.contains('wdbrh61j')), 'trim'] =  'c240'
test.loc[(test.trim.isna()) & (test.vin.str.contains('wdbrh61j')), 'trim'] =  'c240'
train.loc[(train.body.isna()) & (train.vin.str.contains('wdbrh61j')), 'body'] =  'wagon'
test.loc[(test.body.isna()) & (test.vin.str.contains('wdbrh61j')), 'body'] =  'wagon'

train.loc[(train.trim.isna()) & (train.vin.str.contains('wdbrf61j')), 'trim'] =  'c240'
test.loc[(test.trim.isna()) & (test.vin.str.contains('wdbrf61j')), 'trim'] =  'c240'
train.loc[(train.body.isna()) & (train.vin.str.contains('wdbrf61j')), 'body'] =  'sedan'
test.loc[(test.body.isna()) & (test.vin.str.contains('wdbrf61j')), 'body'] =  'sedan'


train.loc[(train.trim.isna()) & (train.vin.str.contains('jm3er293')), 'trim'] =  'grand touring'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jm3er293')), 'trim'] =  'grand touring'
train.loc[(train.body.isna()) & (train.vin.str.contains('jm3er293')), 'body'] =  'suv'
test.loc[(test.body.isna()) & (test.vin.str.contains('jm3er293')), 'body'] =  'suv'


train.loc[(train.trim.isna()) & (train.vin.str.contains('jm1cr29l')), 'trim'] =  'sport'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jm1cr29l')), 'trim'] =  'sport'
train.loc[(train.body.isna()) & (train.vin.str.contains('jm1cr29l')), 'body'] =  'minivan'
test.loc[(test.body.isna()) & (test.vin.str.contains('jm1cr29l')), 'body'] =  'minivan'




train.loc[(train.trim.isna()) & (train.vin.str.contains('jm1fe17n')), 'trim'] =  'rx8'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jm1fe17n')), 'trim'] =  'rx8'
train.loc[(train.body.isna()) & (train.vin.str.contains('jm1fe17n')), 'body'] =  'coupe'
test.loc[(test.body.isna()) & (test.vin.str.contains('jm1fe17n')), 'body'] =  'coupe'


train.loc[(train.trim.isna()) & (train.vin.str.contains('jm1fe173')), 'trim'] =  'rx8'
test.loc[(test.trim.isna()) & (test.vin.str.contains('jm1fe173')), 'trim'] =  'rx8'
train.loc[(train.body.isna()) & (train.vin.str.contains('jm1fe173')), 'body'] =  'coupe'
test.loc[(test.body.isna()) & (test.vin.str.contains('jm1fe173')), 'body'] =  'coupe'

# %% [markdown]
# ### создадим отдельные столбцы с первыми тремя (указывают на производителя) и первыми 8-ю символами вин-номера (указывают на модель и модификацию)

# %%
def vin(value):
    return value[:3]

def vin8(value):
    return value[:8]

# %%
train['vin_8'] = train.vin.apply(vin8)
test['vin_8'] = test.vin.apply(vin8)

train['vin_3'] = train.vin.apply(vin)
test['vin_3'] = test.vin.apply(vin)

# %%
# Используя новые столбцы, заполним пропуски и неявные дубликаты
ford_sp = ['1fm','1fd','1ft','2fa']    
chevrolet_sp = ['3gn', '1g1', '1gb', '1gc'] 
chrysler_sp = ['2c4','1c4','2c8','2a4']    
cadillac_sp = ['1gy','1g6']     
mazda = ['jm1','jm3']    
dodge_sp = ['2d4','2d8','1b4']   


def make(val):
    if val in ford_sp:
        return 'ford'
    elif val in chevrolet_sp:
        return 'chevrolet'
    elif val in chrysler_sp:
        return 'chrysler'
    elif val in cadillac_sp:
        return 'cadillac'
    elif val in mazda:
        return 'mazda'
    elif val in dodge_sp:
        return 'dodge'
    elif val == 'sal':
        return 'land rover'
    elif val == '4a3':
        return 'mitsubishi'
    elif val == 'wba':
        return 'bmw'
    elif val == 'jtj':
        return 'toyota'
    elif val == '1j4':
        return 'jeep'
    elif val == '2hk':
        return 'honda'
    elif val == 'jf1':
        return 'subaru'
    elif val == 'wdb':
        return 'mercedes'
    elif val == 'jn1':
        return 'nissan'
    elif val == '2g1':
        return 'pontiac'
    elif val == 'wp0':
        return 'porsche'
    else:
        pass

# %%
train.loc[train.make.isna(),'make'] = train[train.make.isna()]['vin_3'].apply(make)
test.loc[test.make.isna(),'make'] = test[test.make.isna()]['vin_3'].apply(make)

# %%
train.shape
# Out:
# (440236, 17)

# %%
# удаляем пропуски в make
train.dropna(subset='make',inplace=True)

# %%
train.shape
# Out:
# (438390, 17)

# %%
train[train.model.isna()]['vin_8'].value_counts().head(15)
# Out:
# 4a32b2ff    381
# jtjbt20x    281
# wbakb8c5    131
# jm3er293    108
# 2c4rdgdg    105
# wdbrf52h     95
# jn1az34d     89
# 2c8gf684     86
# wbakc8c5     86
# 1gyee637     85
# 3gnda23d     77
# 2c4gm684     75
# 3gnda13d     70
# jm1fe173     68
# 2a4gm684     67
# Name: vin_8, dtype: int64

# %%
train[train.vin_8.str.contains('3gnda13d')]['trim'].value_counts()
# Out:
# ls    56
# Name: trim, dtype: int64

# %%
train[train.vin_8.str.contains('2a4gm684')]['body'].unique()
# Out:
# array([nan], dtype=object)

# %%
train[train.vin_8.str.contains('2a4gm684')]
# Out:
#         year      make     model            trim body transmission  \
# 1192    2006  chrysler       NaN             NaN  NaN    automatic
# 5288    2006  chrysler       NaN             NaN  NaN    automatic
# 14977   2006  chrysler  pacifica  fwd v6 touring  NaN    automatic
# 23281   2006  chrysler       NaN             NaN  NaN    automatic
# 28626   2006  chrysler       NaN             NaN  NaN    automatic
# ...      ...       ...       ...             ...  ...          ...
# 429512  2006  chrysler       NaN             NaN  NaN    automatic
# 431022  2006  chrysler       NaN             NaN  NaN    automatic
# 433853  2006  chrysler       NaN             NaN  NaN    automatic
# 436936  2006  chrysler       NaN             NaN  NaN    automatic
# 437073  2006  chrysler       NaN             NaN  NaN    automatic
#
#                       vin state  condition  odometer   color interior  \
# 1192    2a4gm68466r720652    az        2.4   80048.0    blue    black
# ...

# %%
# используя вин-номер, заполним модель, модификацию  и кузов
def get_model(val):
  
    if val == '4a32b2ff':
        x= ['galant','fe','sedan']
        return x[0]
    elif val == 'jtjbt20x':
        x= ['gx 470','470','suv']
        return x[0]
    elif val == 'wbakb8c5':
        x= ['7 Series','750li','sedan']
        return x[0]
    elif val == 'jm3er293':
        x= ['cx-7','grand touring','suv']
        return x[0]
    elif val == '2c4rdgdg':
        x= ['grand caravan','crew','minivan']
        return x[0]
    elif val == 'wdbrf52h':
        x= ['c-class','c230 sport','sedan']
        return x[0]
    elif val == 'jn1az34d':
        x= ['350Z','4x2','coupe']
        return x[0]
    elif val == '2c8gf684':
        x= ['pacifica','awd','suv']
        return x[0]
    elif val == 'wbakc8c5':
        x= ['7 series','750li xdrive','sedan']
        return x[0]
    elif val == '1gyee637':
        x= ['srx','v6','suv']
        return x[0]
    elif val == '3gnda23d':
        x= ['hhr','lt','wagon']
        return x[0]
    elif val == '3gnda23d':
        x= ['rx8','rx8','coupe']
        return x[0]
    elif val == '2a4gm684':
        x= ['pacifica','fwd v6 touring','suv']
        return x[0]
    else:
        pass
    
def get_trim(val):
  
    if val == '4a32b2ff':
        x= ['galant','fe','sedan']
        return x[1]
    elif val == 'jtjbt20x':
        x= ['gx 470','470','suv']
        return x[1]
    elif val == 'wbakb8c5':
        x= ['7 Series','750li','sedan']
        return x[1]
    elif val == 'jm3er293':
        x= ['cx-7','grand touring','suv']
        return x[1]
    elif val == '2c4rdgdg':
        x= ['grand caravan','crew','minivan']
        return x[1]
    elif val == 'wdbrf52h':
        x= ['c-class','c230 sport','sedan']
        return x[1]
    elif val == 'jn1az34d':
        x= ['350Z','4x2','coupe']
        return x[1]
    elif val == '2c8gf684':
        x= ['pacifica','awd','suv']
        return x[1]
    elif val == 'wbakc8c5':
        x= ['7 series','750li xdrive','sedan']
        return x[1]
    elif val == '1gyee637':
        x= ['srx','v6','suv']
        return x[1]
    elif val == '3gnda23d':
        x= ['hhr','lt','wagon']
        return x[1]
    elif val == '3gnda23d':
        x= ['rx8','rx8','coupe']
        return x[1]
    elif val == '2a4gm684':
        x= ['pacifica','fwd v6 touring','suv']
        return x[1]
    else:
        pass
    
def get_body(val):
  
    if val == '4a32b2ff':
        x= ['galant','fe','sedan']
        return x[2]
    elif val == 'jtjbt20x':
        x= ['gx 470','470','suv']
        return x[2]
    elif val == 'wbakb8c5':
        x= ['7 Series','750li','sedan']
        return x[2]
    elif val == 'jm3er293':
        x= ['cx-7','grand touring','suv']
        return x[2]
    elif val == '2c4rdgdg':
        x= ['grand caravan','crew','minivan']
        return x[2]
    elif val == 'wdbrf52h':
        x= ['c-class','c230 sport','sedan']
        return x[2]
    elif val == 'jn1az34d':
        x= ['350Z','4x2','coupe']
        return x[2]
    elif val == '2c8gf684':
        x= ['pacifica','awd','suv']
        return x[2]
    elif val == 'wbakc8c5':
        x= ['7 series','750li xdrive','sedan']
        return x[2]
    elif val == '1gyee637':
        x= ['srx','v6','suv']
        return x[2]
    elif val == '3gnda23d':
        x= ['hhr','lt','wagon']
        return x[2]
    elif val == '3gnda23d':
        x= ['rx8','rx8','coupe']
        return x[2]
    elif val == '2a4gm684':
        x= ['pacifica','fwd v6 touring','suv']
        return x[2]
    else:
        pass

# %%
train[train.model.isna() & (train.vin_8 == '1gyee637')]['vin_8'].apply(get_trim)
# Out:
# 5627      v6
# 8312      v6
# 10378     v6
# 12145     v6
# 22766     v6
#           ..
# 411093    v6
# 416889    v6
# 418917    v6
# 428448    v6
# 435169    v6
# Name: vin_8, Length: 85, dtype: object

# %%
# используя вин-номер, заполним модель, модификацию  и кузов
train.loc[train.model.isna(),'model'] = train[train.model.isna()]['vin_8'].apply(get_model)
test.loc[test.model.isna(),'model'] = test[test.model.isna()]['vin_8'].apply(get_model)
train.loc[train.model.isna(),'trim'] = train[train.model.isna()]['vin_8'].apply(get_trim)
test.loc[test.model.isna(),'trim'] = test[test.model.isna()]['vin_8'].apply(get_trim)
train.loc[train.model.isna(),'body'] = train[train.model.isna()]['vin_8'].apply(get_body)
test.loc[test.model.isna(),'body'] = test[test.model.isna()]['vin_8'].apply(get_body)

# %%
train[train.model.isna()]
# Out:
#         year        make model  trim  body transmission                vin  \
# 42      2007       mazda  None  None  None       manual  jm1bk34l671745431
# 63      2011        ford  None  None  None    automatic  1fdne1bw5bda64735
# 64      2008   chevrolet  None  None  None    automatic  1gbdv13wx8d142776
# 111     2006   chevrolet  None  None  None    automatic  3gnda13d36s611801
# 161     2007  land rover  None  None  None    automatic  salsk25467a105097
# ...      ...         ...   ...   ...   ...          ...                ...
# 440084  2004   chevrolet  None  None  None    automatic  1g1yy22g445131628
# 440085  2011        ford  None  None  None    automatic  1fdne1bw8bdb21610
# 440118  2004    cadillac  None  None  None    automatic  1gyde637240130408
# 440122  2007  land rover  None  None  None    automatic  salme15487a251642
# 440144  2004    chrysler  None  None  None    automatic  2c4gm68474r511987
#
#        state  condition  odometer   color interior  \
# ...

# %%
train.shape
# Out:
# (438390, 17)

# %%
# удалим оставшиеся пропуски в model
train.dropna(subset='model',inplace=True)

# %%
train.shape
# Out:
# (433784, 17)

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.218542
# body                  body         0.656087
# transmission  transmission        11.593097
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.154298
# odometer          odometer         0.015445
# color                color         0.132093
# interior          interior         0.132093
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train[train.odometer.isna()]
# Out:
#         year        make           model         trim          body  \
# 36557   2002        ford        windstar  lx standard       minivan
# 42825   1997      toyota           camry           ce         sedan
# 46266   2001        ford         mustang       deluxe   convertible
# 60990   2014        ford          fiesta           st     hatchback
# 64540   1998   chevrolet          blazer           ls           suv
# ...      ...         ...             ...          ...           ...
# 421174  2002        jeep         liberty      limited           suv
# 422491  2001     pontiac           aztek         base           suv
# 422735  2014  volkswagen           jetta      se pzev         sedan
# 423407  1998     pontiac         sunfire           se         coupe
# 439240  2004   chevrolet  silverado 1500           ls  extended cab
#
#        transmission                vin state  condition  odometer   color  \
# 36557     automatic  2fmza51442ba27119    fl        NaN       NaN   beige
# ...

# %%
train.shape
# Out:
# (433784, 17)

# %%
# удалим пропуски в одометре
train.dropna(subset='odometer',inplace=True)

# %%
train.shape
# Out:
# (433717, 17)

# %%
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.443403
# model                model         1.491941
# trim                  trim         1.688201
# body                  body         2.095259
# transmission  transmission        11.821948
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.161588
# odometer          odometer         0.017264
# color                color         0.143561
# interior          interior         0.143561
# seller              seller         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
# заполним наиболее часто встречающимися знаечниями пропуски
train.make.fillna('base', inplace = True)
test.make.fillna('base', inplace = True)

# %%
# заполним наиболее часто встречающимися знаечниями пропуски
train.trim.fillna('base', inplace = True)
test.trim.fillna('base', inplace = True)

# %%
# заполним unknown пропуски
train.model.fillna('unknown', inplace = True)
test.model.fillna('unknown', inplace = True)

# %%
# заполним наиболее часто встречающимися знаечниями пропуски

train.body.fillna('sedan', inplace = True)
test.body.fillna('sedan', inplace = True)

# %%
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         0.000000
# transmission  transmission        11.821948
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.161588
# odometer          odometer         0.017264
# color                color         0.143561
# interior          interior         0.143561
# seller              seller         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train.body.unique()
# Out:
# array(['suv', 'sedan', 'wagon', 'minivan', 'extended cab', 'regular cab',
#        'coupe', 'supercrew', 'convertible', 'crew cab', 'supercab',
#        'hatchback', 'g coupe', 'g convertible', 'access cab', 'g sedan',
#        'e-series van', 'quad cab', 'tsx sport wagon', 'van', 'cts coupe',
#        'koup', 'king cab', 'double cab', 'elantra coupe', 'crewmax cab',
#        'genesis coupe', 'g37 coupe', 'club cab', 'beetle convertible',
#        'mega cab', 'regular-cab', 'xtracab', 'q60 coupe',
#        'promaster cargo van', 'cts-v coupe', 'cts wagon', 'cab plus 4',
#        'g37 convertible', 'transit van', 'q60 convertible', 'cab plus',
#        'ram van', 'granturismo convertible', 'cts-v wagon'], dtype=object)

# %% [markdown]
# train.body = train.body.fillna('unknown')
# test.body = test.body.fillna('unknown')

# %%
# унифицируем типы кузовов
def name_body(row):
    if isinstance(row, float):
        pass # Можно изменить на нужный маркер для значений типа float
    elif 'suv' in row:
        return "suv"
    elif 'sedan' in row:
        return "sedan"
    elif 'wagon' in row:
        return 'wagon'
    elif 'minivan' in row:
        return "minivan"
    elif 'coupe' in row:
        return 'coupe'
    elif 'convertible' in row:
        return "convertible"
    elif 'hatchback' in row:
        return 'hatchback'
    elif 'cab' in row:
        return 'cab'
    elif 'van' in row:
        return 'van'
    else:
        pass
train['body'] = train['body'].apply(name_body)
train.body.value_counts()

test['body'] = test['body'].apply(name_body)
test.body.value_counts()
# Out:
# sedan          51448
# suv            28364
# cab             7471
# hatchback       5152
# minivan         5096
# coupe           3994
# wagon           3287
# convertible     2149
# van             1323
# Name: body, dtype: int64

# %%
test.body.unique()
# Out:
# array(['sedan', 'van', 'suv', 'cab', 'wagon', 'hatchback', 'convertible',
#        'minivan', 'coupe', None], dtype=object)

# %%
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.611877
# transmission  transmission        11.821948
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.161588
# odometer          odometer         0.017264
# color                color         0.143561
# interior          interior         0.143561
# seller              seller         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.663527
# transmission  transmission        11.588893
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.143564
# odometer          odometer         0.000000
# color                color         0.130500
# interior          interior         0.130500
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train[train.body.isna()]
# Out:
#         year  make  model     trim  body transmission                vin  \
# 26      2012  ford  f-150      xlt  None    automatic  1ftfw1cfxcfc23663
# 32      2013  ford  f-150      xlt  None    automatic  1ftfw1ct8dkd06233
# 181     2009  ford  f-150      xlt  None    automatic  1ftrw14849fa35954
# 301     2011  ford  f-150      fx2  None    automatic  1ftfw1ct7bke18082
# 321     2013  ford  f-150      xlt  None    automatic  1ftfw1ef8dfb68158
# ...      ...   ...    ...      ...   ...          ...                ...
# 439807  2007  ford  f-150   lariat  None    automatic  1ftpw12vx7ka80191
# 439872  2011  ford  f-150      xlt  None    automatic  1ftfw1ef6bke14418
# 439972  2014  ford  f-150      xlt  None          NaN  1ftfw1ef3efa19531
# 440003  2011  ford  f-150   lariat  None    automatic  1ftfw1et3bfb27536
# 440094  2010   kia  forte  koup sx  None    automatic  knafw6a38a5199367
#
#        state  condition  odometer  color interior  \
# ...

# %%
train.transmission.unique()
# Out:
# array(['automatic', nan, 'manual'], dtype=object)

# %%
train.transmission.value_counts()
# Out:
# automatic    370122
# manual        13332
# Name: transmission, dtype: int64

# %%
train[train.transmission.isna()]
# Out:
#         year       make           model          trim         body  \
# 13      2006  chevrolet  silverado 1500            ls          cab
# 27      2014      dodge         charger           sxt        sedan
# 31      2012   mercedes        gl-class  gl450 4matic          suv
# 49      2007  chevrolet  silverado 1500           ltz          cab
# 53      2013       ford         mustang            v6  convertible
# ...      ...        ...             ...           ...          ...
# 440178  2011   mercedes       glk-class        glk350          suv
# 440184  2008     toyota           camry            le        sedan
# 440186  2015   chrysler             200       limited        sedan
# 440206  1997       ford           f-150            xl          cab
# 440213  2012     nissan          sentra        2.0 sr        sedan
#
#        transmission                vin state  condition  odometer   color  \
# 13              NaN  1gcek19bx6z269153    tx        2.2  166999.0   white
# ...

# %%
#заполним коробкой автомат , так как механика намного реже применяется 
train.transmission.fillna('automatic', inplace=True)
test.transmission.fillna('automatic', inplace=True)

# %%
train.shape
# Out:
# (433717, 17)

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.663527
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.143564
# odometer          odometer         0.000000
# color                color         0.130500
# interior          interior         0.130500
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.611877
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.161588
# odometer          odometer         0.017264
# color                color         0.143561
# interior          interior         0.143561
# seller              seller         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train.condition.unique()
# Out:
# array([4.2, 3.5, 2.2, 2.8, 2. , 2.5, 3.4, 4.8, 1.9, 1. , 2.7, 3.6, 2.9,
#        4.1, 2.6, 2.1, 3. , 4.9, 4.7, 4. , 3.3, 3.8, 3.7, 4.5, 4.6, 5. ,
#        4.3, 2.4, 2.3, 3.9, 3.1, nan, 3.2, 4.4, 1.4, 1.5, 1.7, 1.2, 1.3,
#        1.6, 1.8, 1.1])

# %%
train.condition.value_counts()
# Out:
# 1.9    32196
# 3.5    20782
# 3.7    20190
# 4.4    19902
# 4.3    19614
# 4.2    19224
# 3.6    18012
# 4.1    17974
# 2.0    15761
# 4.0    15633
# 3.9    15506
# 2.8    14755
# 3.8    14641
# 2.9    14578
# 3.4    13480
# 2.7    12559
# 4.9    10216
# 4.8     9976
# 4.6     9840
# 2.5     9682
# 4.5     9600
# 2.6     9244
# 4.7     8998
# 5.0     8769
# 3.3     8328
# 3.0     8272
# 3.2     7742
# 2.4     7230
# 3.1     7159
# 2.1     7070
# 2.3     6286
# 1.0     5586
# 2.2     4620
# 1.8      246
# 1.7      188
# 1.6      128
# 1.5      118
# 1.4      101
# 1.2       74
# 1.1       74
# 1.3       66
# Name: condition, dtype: int64

# %%
train[train.condition.isna()]
# Out:
#         year       make           model             trim       body  \
# 89      1999   mercedes          e300dt             base      sedan
# 122     2007     suzuki            reno             base  hatchback
# 298     2006  chevrolet  silverado 1500              lt3        cab
# 303     2013        kia         sorento               lx        suv
# 326     2005       jeep         liberty            sport        suv
# ...      ...        ...             ...              ...        ...
# 439900  2001   infiniti             i30             base      sedan
# 439920  2013  chevrolet  silverado 1500               lt        cab
# 440145  2010      mazda               3  s grand touring  hatchback
# 440166  2005     nissan          maxima           3.5 sl      sedan
# 440223  2000       audi              a4     1.8t quattro      sedan
#
#        transmission                vin state  condition  odometer     color  \
# ...

# %%
# 
train[~train.condition.isna()]['odometer'].describe()
# Out:
# count    424420.000000
# mean      66548.692736
# std       52435.591474
# min           1.000000
# 25%       27706.000000
# 50%       50324.500000
# 75%       96392.250000
# max      999999.000000
# Name: odometer, dtype: float64

# %%
train[train.condition.isna()]['odometer'].describe()
# Out:
# count      9297.000000
# mean     117652.070560
# std       57688.165259
# min           1.000000
# 25%       81476.000000
# 50%      115895.000000
# 75%      152525.000000
# max      999999.000000
# Name: odometer, dtype: float64

# %%
train[~train.condition.isna()]
# Out:
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# 440231  2013     kia             optima  ex hybrid  sedan    automatic
# 440232  2014    mini  cooper countryman     s all4  wagon    automatic
# 440233  2008     bmw           6 series       650i  coupe    automatic
# 440234  2014     ram               2500        slt    cab    automatic
# 440235  2013  nissan              rogue         sv    suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
train.loc[train['condition'].isna()==True]['odometer'].unique()
test.loc[test['condition'].isna()==True]['odometer'].unique()
# Out:
# array([ 89590.,  76674., 181267., ..., 133449.,  25288., 109184.])

# %%
# заменим све значения одометра 1 на Nan
train.loc[train['odometer']==1,'odometer']= np.nan

# %%
test.loc[test['odometer']==1,'odometer']= np.nan

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.663527
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.143564
# odometer          odometer         0.231487
# color                color         0.130500
# interior          interior         0.130500
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.611877
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.161588
# odometer          odometer         0.240782
# color                color         0.143561
# interior          interior         0.143561
# seller              seller         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train[train.odometer==10.0  ]
# Out:
#         year       make           model                       trim       body  \
# 12249   2000     toyota           camry                      le v6      sedan
# 45263   2014       jeep         patriot                      sport        suv
# 80292   2014    hyundai          accent                         se  hatchback
# 137509  2014    hyundai        santa fe                      sport        suv
# 159363  2014     nissan          sentra                         sl      sedan
# 214777  2014       ford            flex                    limited      wagon
# 233926  2015    hyundai          sonata                 sport pzev      sedan
# 250023  2015      dodge            dart                        sxt      sedan
# 267561  2015      honda             fit                         ex  hatchback
# 305190  2015       ford          fusion                         se      sedan
# 311333  1998      buick         century                     custom      sedan
# ...

# %%
train[train.odometer.isna()]
# Out:
#         year        make     model           trim     body transmission  \
# 125     2000        jeep  cherokee          sport      suv    automatic
# 212     2007         gmc     yukon            sle      suv    automatic
# 270     2000      nissan    altima            gxe    sedan    automatic
# 788     2013     hyundai    accent            gls    sedan    automatic
# 993     1997      toyota     camry            xle    sedan    automatic
# ...      ...         ...       ...            ...      ...          ...
# 438289  2002       acura        rl            3.5    sedan    automatic
# 439216  1999  oldsmobile  intrigue           base    sedan    automatic
# 439366  2002      toyota     camry             se    sedan    automatic
# 439525  2005      nissan     quest         3.5 se  minivan    automatic
# 439922  2001       honda    accord  value package    sedan    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
train.color.unique()
# Out:
# array(['black', 'gold', 'silver', 'blue', 'white', 'gray', '—', 'red',
#        'brown', 'green', 'beige', nan, 'off-white', 'yellow', 'burgundy',
#        'orange', 'charcoal', 'purple', 'turquoise', 'lime', 'pink'],
#       dtype=object)

# %%
train.color.value_counts()
# Out:
# black        86011
# white        82682
# silver       64769
# gray         64628
# blue         39527
# red          33959
# —            19399
# gold          8704
# green         8661
# beige         7110
# burgundy      6948
# brown         5260
# orange        1584
# purple        1232
# off-white     1131
# yellow         940
# charcoal       384
# turquoise      176
# pink            32
# lime            14
# Name: color, dtype: int64

# %%
train[train.color.isna()]
# Out:
#         year       make     model        trim         body transmission  \
# 134     2013   mercedes  sl-class       sl550  convertible    automatic
# 1027    2015      lexus    lx 570        base          suv    automatic
# 1722    2012  chevrolet    malibu          ls        sedan    automatic
# 1772    2013   mercedes   m-class       ml350          suv    automatic
# 2624    2013  chevrolet   equinox         ltz          suv    automatic
# ...      ...        ...       ...         ...          ...          ...
# 437488  2011   mercedes   c-class  c350 sport        sedan    automatic
# 437596  2013        kia      soul           +        wagon    automatic
# 438095  1999   cadillac   deville    concours        sedan    automatic
# 439242  2009       ford    ranger         xlt          cab    automatic
# 440026  2013       ford  explorer         xlt          suv    automatic
#
#                       vin state  condition  odometer color interior  \
# ...

# %%
# заполним самым часто встречающимся цветом
train.color.fillna('black',inplace=True)
test.color.fillna('black',inplace=True)

# %%
train.interior.unique()
# Out:
# array(['black', 'beige', 'gray', 'tan', 'brown', '—', 'off-white', nan,
#        'blue', 'white', 'silver', 'red', 'green', 'gold', 'purple',
#        'orange', 'burgundy', 'yellow'], dtype=object)

# %%
train.interior.value_counts()
# Out:
# black        190552
# gray         138105
# beige         46172
# tan           34091
# —             13271
# brown          6692
# red            1046
# silver          830
# blue            827
# off-white       373
# purple          271
# gold            251
# white           210
# green           187
# burgundy        152
# orange          105
# yellow           16
# Name: interior, dtype: int64

# %%
train[train.interior.isna()]
# Out:
#         year       make     model        trim         body transmission  \
# 134     2013   mercedes  sl-class       sl550  convertible    automatic
# 1027    2015      lexus    lx 570        base          suv    automatic
# 1722    2012  chevrolet    malibu          ls        sedan    automatic
# 1772    2013   mercedes   m-class       ml350          suv    automatic
# 2624    2013  chevrolet   equinox         ltz          suv    automatic
# ...      ...        ...       ...         ...          ...          ...
# 437488  2011   mercedes   c-class  c350 sport        sedan    automatic
# 437596  2013        kia      soul           +        wagon    automatic
# 438095  1999   cadillac   deville    concours        sedan    automatic
# 439242  2009       ford    ranger         xlt          cab    automatic
# 440026  2013       ford  explorer         xlt          suv    automatic
#
#                       vin state  condition  odometer  color interior  \
# ...

# %%
# заполним самым часто встречающимся цветом
train.interior.fillna('black',inplace=True)
test.interior.fillna('black',inplace=True)

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.663527
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.143564
# odometer          odometer         0.231487
# color                color         0.000000
# interior          interior         0.000000
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
percent_missing = test.isnull().sum() * 100 / len(test)
missing_value_df = pd.DataFrame({'column_name': test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.611877
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.161588
# odometer          odometer         0.240782
# color                color         0.000000
# interior          interior         0.000000
# seller              seller         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train.seller.unique()
# Out:
# array(['santander consumer', 'ars/avis budget group',
#        'nissan-infiniti lt', ..., 'autostar enterprises',
#        'kocourek nissan', 'studio city auto group'], dtype=object)

# %%
train.seller.value_counts()
# Out:
# nissan-infiniti lt                       15823
# ford motor credit company,llc            15266
# the hertz corporation                    14683
# santander consumer                       12093
# avis corporation                         10091
#                                          ...
# onemain rem/premier motors inc               1
# napleton's schaumburg pontiac gmc inc        1
# mercedes-benz of tri-cities                  1
# wy hy fcu                                    1
# studio city auto group                       1
# Name: seller, Length: 12882, dtype: int64

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                column_name  percent_missing
# year                  year         0.000000
# make                  make         0.000000
# model                model         0.000000
# trim                  trim         0.000000
# body                  body         1.663527
# transmission  transmission         0.000000
# vin                    vin         0.000000
# state                state         0.000000
# condition        condition         2.143564
# odometer          odometer         0.231487
# color                color         0.000000
# interior          interior         0.000000
# seller              seller         0.000000
# sellingprice  sellingprice         0.000000
# saledate          saledate         0.000000
# vin_8                vin_8         0.000000
# vin_3                vin_3         0.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433717 entries, 0 to 440235
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          433717 non-null  int64
#  1   make          433717 non-null  object
#  2   model         433717 non-null  object
#  3   trim          433717 non-null  object
#  4   body          426502 non-null  object
#  5   transmission  433717 non-null  object
#  6   vin           433717 non-null  object
#  7   state         433717 non-null  object
#  8   condition     424420 non-null  float64
#  9   odometer      432713 non-null  float64
#  10  color         433717 non-null  object
#  11  interior      433717 non-null  object
#  12  seller        433717 non-null  object
#  13  sellingprice  433717 non-null  int64
#  14  saledate      433717 non-null  object
#  15  vin_8         433717 non-null  object
#  16  vin_3         433717 non-null  object
# ...

# %%
train['saledate']
# Out:
# 0         Tue Jun 02 2015 02:30:00 GMT-0700 (PDT)
# 1         Wed Feb 25 2015 02:00:00 GMT-0800 (PST)
# 2         Wed Jun 10 2015 02:30:00 GMT-0700 (PDT)
# 3         Wed Jun 17 2015 03:00:00 GMT-0700 (PDT)
# 4         Tue Feb 03 2015 04:00:00 GMT-0800 (PST)
#                            ...
# 440231    Tue Jan 20 2015 04:30:00 GMT-0800 (PST)
# 440232    Wed Feb 11 2015 02:00:00 GMT-0800 (PST)
# 440233    Tue Mar 03 2015 04:30:00 GMT-0800 (PST)
# 440234    Wed Jan 14 2015 02:05:00 GMT-0800 (PST)
# 440235    Thu Jan 15 2015 02:00:00 GMT-0800 (PST)
# Name: saledate, Length: 433717, dtype: object

# %%
test.shape
# Out:
# (110058, 16)

# %%
# Функция для удаления информации о часовом поясе
def remove_timezone(date_string):
    return re.sub(r'\s*GMT[-+]\d{4}\s*\(.*\)$', '', date_string)

# Функция для преобразования строки в формат datetime
def convert_to_datetime(date_string):
    date_format = "%a %b %d %Y %H:%M:%S"
    return datetime.strptime(date_string, date_format)

# Приведение всех дат к часовому поясу UTC
train.loc[:, 'saledate'] = train['saledate'].apply(remove_timezone).apply(convert_to_datetime)
train.loc[:, 'saledate'] = train['saledate'].dt.tz_localize('UTC')

test.loc[:, 'saledate'] = test['saledate'].apply(remove_timezone).apply(convert_to_datetime)
test.loc[:, 'saledate'] = test['saledate'].dt.tz_localize('UTC')

# %%
train
# Out:
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# 440231  2013     kia             optima  ex hybrid  sedan    automatic
# 440232  2014    mini  cooper countryman     s all4  wagon    automatic
# 440233  2008     bmw           6 series       650i  coupe    automatic
# 440234  2014     ram               2500        slt    cab    automatic
# 440235  2013  nissan              rogue         sv    suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
train['saledate'].dt.year.value_counts()
# Out:
# 2015    390914
# 2014     42803
# Name: saledate, dtype: int64

# %% [markdown]
# ## полноценный разведочный анализ (EDA)

# %%
train.sellingprice.describe()
# Out:
# count    433717.000000
# mean      13675.152542
# std        9738.687151
# min           1.000000
# 25%        7000.000000
# 50%       12200.000000
# 75%       18250.000000
# max      230000.000000
# Name: sellingprice, dtype: float64

# %%
train = train[train.sellingprice >90]

# %%
train[train.sellingprice <90]
# Out:
# Empty DataFrame
# Columns: [year, make, model, trim, body, transmission, vin, state, condition, odometer, color, interior, seller, sellingprice, saledate, vin_8, vin_3]
# Index: []

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433716 entries, 0 to 440235
# Data columns (total 17 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          433716 non-null  int64
#  1   make          433716 non-null  object
#  2   model         433716 non-null  object
#  3   trim          433716 non-null  object
#  4   body          426501 non-null  object
#  5   transmission  433716 non-null  object
#  6   vin           433716 non-null  object
#  7   state         433716 non-null  object
#  8   condition     424419 non-null  float64
#  9   odometer      432713 non-null  float64
#  10  color         433716 non-null  object
#  11  interior      433716 non-null  object
#  12  seller        433716 non-null  object
#  13  sellingprice  433716 non-null  int64
#  14  saledate      433716 non-null  datetime64[ns, UTC]
#  15  vin_8         433716 non-null  object
#  16  vin_3         433716 non-null  object
# ...

# %%
train.duplicated().sum()
# Out:
# 0

# %%
seller_name = train.seller.value_counts().head(250).index.to_list()

# %%
# заменим названия продавцов с маленьким оборотом авто на 'other'
def rename_seller(a):
    if a in seller_name:
        return a
    else:
        return 'other'

# %%
train.seller = train.seller.apply(rename_seller)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\3981002822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.seller = train.seller.apply(rename_seller)

# %%
train
# Out:
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# 440231  2013     kia             optima  ex hybrid  sedan    automatic
# 440232  2014    mini  cooper countryman     s all4  wagon    automatic
# 440233  2008     bmw           6 series       650i  coupe    automatic
# 440234  2014     ram               2500        slt    cab    automatic
# 440235  2013  nissan              rogue         sv    suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %% [markdown]
# ### визуализируем полученные данные

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=train, x="year")
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
plt.figure(figsize=(12,11))
sns.histplot(data=train, y="make")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='make'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=train, y="body")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='body'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=train, x="condition", bins= 10)
# Out:
# <AxesSubplot:xlabel='condition', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=train, y="color")
# Out:
# <AxesSubplot:xlabel='Count', ylabel='color'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=train, x="odometer", bins= 10,binrange = (1,300_000))
# Out:
# <AxesSubplot:xlabel='odometer', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=test, x="odometer", bins= 10,binrange = (1,300_000))
# Out:
# <AxesSubplot:xlabel='odometer', ylabel='Count'>

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=train, x="sellingprice", bins= 16,binrange = (1,80_000))
# Out:
# <AxesSubplot:xlabel='sellingprice', ylabel='Count'>

# %%
sns.boxplot(x=train['sellingprice'])
# Out:
# <AxesSubplot:xlabel='sellingprice'>

# %%
sns.boxplot(x=train['odometer'])
# Out:
# <AxesSubplot:xlabel='odometer'>

# %%
sns.boxplot(x=test['odometer'])
# Out:
# <AxesSubplot:xlabel='odometer'>

# %%
plt.figure(figsize=(12,8))
sns.heatmap(train.corr().round(2),annot=True,square=True)
# Out:
# <AxesSubplot:>

# %%
pd.plotting.scatter_matrix(train, figsize=(12, 9));

# %%
# добавим столбец года продажи
train['sale_year'] = pd.DatetimeIndex(train['saledate']).year
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\1047475864.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['sale_year'] = pd.DatetimeIndex(train['saledate']).year

# %%
test['sale_year'] = pd.DatetimeIndex(test['saledate']).year

# %%
train
# Out:
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# 440231  2013     kia             optima  ex hybrid  sedan    automatic
# 440232  2014    mini  cooper countryman     s all4  wagon    automatic
# 440233  2008     bmw           6 series       650i  coupe    automatic
# 440234  2014     ram               2500        slt    cab    automatic
# 440235  2013  nissan              rogue         sv    suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
# добавим столбец возоаста авто
train['age'] =  train['sale_year'] - train['year']
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\4066617096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['age'] =  train['sale_year'] - train['year']

# %%
test['age'] =  test['sale_year'] - test['year']

# %%
# заменим отрицательные значения возрастa на 0
train.loc[train['age'] == -1, 'age'] = 0
test.loc[test['age'] == -1, 'age'] = 0

# %%
# В зависимости от возраста заменим пропуски в состоянии медианным значением
train.loc[train.condition.isna() & (train.age <= 1), 'condition'] = train.loc[train.age <= 1, 'condition'].fillna(train['condition'].median())
test.loc[test.condition.isna() & (test.age <= 1), 'condition'] = test.loc[(test.age <= 1), 'condition'].fillna(test['condition'].median())
train.loc[train.condition.isna() & (train.age < 10) & (train.age > 1), 'condition'] = train.loc[(train.age < 10)  & (train.age > 1), 'condition'].fillna(train['condition'].median())
test.loc[test.condition.isna() & (test.age < 10) & (test.age > 1), 'condition'] = test.loc[(test.age < 10) & (test.age > 1), 'condition'].fillna(test['condition'].median())
train.loc[train.condition.isna() & (train.age >= 10), 'condition'] = 1
test.loc[test.condition.isna() & (test.age >= 10), 'condition'] = 1

# %%
train
# Out:
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# 440231  2013     kia             optima  ex hybrid  sedan    automatic
# 440232  2014    mini  cooper countryman     s all4  wagon    automatic
# 440233  2008     bmw           6 series       650i  coupe    automatic
# 440234  2014     ram               2500        slt    cab    automatic
# 440235  2013  nissan              rogue         sv    suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
# округлим до целых состояние авто
train.condition = round(train.condition)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\3879261550.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.condition = round(train.condition)

# %%
test.condition = round(test.condition)

# %%
train.condition.unique()
# Out:
# array([4., 2., 3., 5., 1.])

# %%
train
# Out:
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# 440231  2013     kia             optima  ex hybrid  sedan    automatic
# 440232  2014    mini  cooper countryman     s all4  wagon    automatic
# 440233  2008     bmw           6 series       650i  coupe    automatic
# 440234  2014     ram               2500        slt    cab    automatic
# 440235  2013  nissan              rogue         sv    suv    automatic
#
#                       vin state  condition  odometer   color interior  \
# ...

# %%
train.odometer.describe()
# Out:
# count    432713.000000
# mean      67801.074770
# std       53033.549794
# min           2.000000
# 25%       28205.000000
# 50%       51538.000000
# 75%       98304.000000
# max      999999.000000
# Name: odometer, dtype: float64

# %%
# категоризация авто на основании пробега
def odometer_group(value):
    
    if (value > 1) & (value <= 32_000):
        return  "A"
    elif (value > 32_000) & (value <= 93_500):
        return "B"
    elif (value > 93_500) & (value <= 190_000):
        return "C"
    elif (value > 190_000) & (value <= 400_000):
        return "D"
    elif (value > 400_000) :
        return "E"

    else:
         return np.nan

# %%
# заполнение пропусков категорий пробега в зависимости от возраста
def fil_odometer_group(value):
    
    if (value >= 0) & (value <2):
        return  "A"
    elif (value >=2) & (value < 6):
        return "B"
    elif (value >=6) & (value < 11):
        return "C"
    elif (value >=11) & (value <13):
        return "D"
    elif (value >=13):
        return "E"
  
    else:
         return np.nan

# %%
train['odometer_group'] = train['odometer'].apply(odometer_group)
train
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\2951386259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train['odometer_group'] = train['odometer'].apply(odometer_group)
#         year    make              model       trim   body transmission  \
# 0       2011    ford               edge        sel    suv    automatic
# 1       2014    ford             fusion         se  sedan    automatic
# 2       2012  nissan             sentra     2.0 sl  sedan    automatic
# 3       2003  hummer                 h2       base    suv    automatic
# 4       2007    ford             fusion        sel  sedan    automatic
# ...      ...     ...                ...        ...    ...          ...
# ...

# %%
test['odometer_group'] = test['odometer'].apply(odometer_group)

# %%
train.loc[train['odometer_group'].isna(),'odometer_group'] = train[train['odometer_group'].isna()]['age'].apply(fil_odometer_group)
test.loc[test['odometer_group'].isna(),'odometer_group'] = test[test['odometer_group'].isna()]['age'].apply(fil_odometer_group)

# %%
# заполнение пропускрв в колонке состояния в зависимости от группы пробега
def fil_cond_group(value):
    
    if value == 'A':
        return  5.0
    elif value == 'B':
        return  4.0
    elif value == 'C':
        return  3.0
    elif value == 'D':
        return  2.0
    elif value == 'E':
        return  1.0
    else:
         return np.nan

# %%
train.loc[train['condition'].isna(),'condition'] = train[train['condition'].isna()]['odometer_group'].apply(fil_cond_group)
test.loc[test['condition'].isna(),'condition'] = test[test['condition'].isna()]['odometer_group'].apply(fil_cond_group)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\3722642405.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train['condition'].isna(),'condition'] = train[train['condition'].isna()]['odometer_group'].apply(fil_cond_group)

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                    column_name  percent_missing
# year                      year         0.000000
# make                      make         0.000000
# model                    model         0.000000
# trim                      trim         0.000000
# body                      body         1.663531
# transmission      transmission         0.000000
# vin                        vin         0.000000
# state                    state         0.000000
# condition            condition         0.000000
# odometer              odometer         0.231257
# color                    color         0.000000
# interior              interior         0.000000
# seller                  seller         0.000000
# sellingprice      sellingprice         0.000000
# saledate              saledate         0.000000
# vin_8                    vin_8         0.000000
# vin_3                    vin_3         0.000000
# sale_year            sale_year         0.000000
# age                        age         0.000000
# ...

# %%
# заполнение пропусков в столбце одометра на медианное значение

train.loc[:, 'odometer'].fillna(train['odometer'].median(), inplace=True)
test.loc[:, 'odometer'].fillna(test['odometer'].median(), inplace=True)
# Out:
# C:\Users\Андрей\AppData\Local\Temp\ipykernel_7760\3082740900.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[:, 'odometer'].fillna(train['odometer'].median(), inplace=True)

# %%
percent_missing = train.isnull().sum() * 100 / len(train)
missing_value_df = pd.DataFrame({'column_name': train.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                    column_name  percent_missing
# year                      year         0.000000
# make                      make         0.000000
# model                    model         0.000000
# trim                      trim         0.000000
# body                      body         1.663531
# transmission      transmission         0.000000
# vin                        vin         0.000000
# state                    state         0.000000
# condition            condition         0.000000
# odometer              odometer         0.000000
# color                    color         0.000000
# interior              interior         0.000000
# seller                  seller         0.000000
# sellingprice      sellingprice         0.000000
# saledate              saledate         0.000000
# vin_8                    vin_8         0.000000
# vin_3                    vin_3         0.000000
# sale_year            sale_year         0.000000
# age                        age         0.000000
# ...

# %%
train[train['odometer']>500_000]
# Out:
#         year        make            model           trim         body  \
# 6069    2012     hyundai           sonata            gls        sedan
# 9830    2002      saturn              vue           base          suv
# 11122   2004   chevrolet            tahoe             ls          suv
# 12368   2006       mazda          tribute              i          suv
# 14897   2006         kia           amanti           base        sedan
# 17341   1996      toyota          corolla           base        sedan
# 26602   2005      nissan            quest         3.5 se      minivan
# 45730   2001   chevrolet   silverado 1500             ls          cab
# 66088   2009   chevrolet           cobalt             lt        coupe
# 78696   2006      nissan            quest         3.5 se      minivan
# 79958   2011      nissan           altima          2.5 s        sedan
# 84696   2005      nissan            quest         3.5 se      minivan
# ...

# %%
train.shape
# Out:
# (433716, 20)

# %%
train = train[train['odometer']<500_000]

# %%
train.shape
# Out:
# (433656, 20)

# %%
# замена пропусков в кузове
train.loc[(train.body.isna()) & (train.model == 'f-150'), 'body'] = 'cab'
test.loc[(test.body.isna()) & (test.model == 'f-150'), 'body'] = 'cab'
train.loc[(train.body.isna()) & (train.model == 'forte'), 'body'] = 'coupe'
test.loc[(test.body.isna()) & (test.model == 'forte'), 'body'] = 'coupe'

# %%
sns.boxplot(x=train['odometer'])
# Out:
# <AxesSubplot:xlabel='odometer'>

# %%
train.make.value_counts()
# Out:
# ford            74042
# chevrolet       47872
# nissan          42946
# toyota          31983
# dodge           24289
# honda           21597
# hyundai         17184
# bmw             16466
# kia             14319
# chrysler        14051
# mercedes        13499
# infiniti        12122
# jeep            12105
# volkswagen       9900
# lexus            9362
# gmc              8366
# mazda            6810
# cadillac         6043
# acura            4679
# audi             4634
# lincoln          4541
# subaru           4019
# buick            4016
# mitsubishi       3792
# pontiac          3592
# ram              3592
# volvo            2957
# mini             2473
# saturn           2244
# mercury          1560
# land rover       1475
# scion            1338
# jaguar           1100
# porsche          1094
# suzuki            846
# fiat              672
# hummer            597
# saab              384
# smart             311
# oldsmobile        294
# isuzu             163
# ...

# %%
train.loc[train.odometer > 200_000,'odometer'] = 200_000

# %%
sns.boxplot(x=train['odometer'])
# Out:
# <AxesSubplot:xlabel='odometer'>

# %%
sns.boxplot(x=train['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
sns.boxplot(x=train['condition'])
# Out:
# <AxesSubplot:xlabel='condition'>

# %%
pd.plotting.scatter_matrix(train, figsize=(12, 9));
# Out:
# array([[<AxesSubplot:xlabel='year', ylabel='year'>,
#         <AxesSubplot:xlabel='odometer', ylabel='year'>,
#         <AxesSubplot:xlabel='sellingprice', ylabel='year'>,
#         <AxesSubplot:xlabel='sale_year', ylabel='year'>,
#         <AxesSubplot:xlabel='age', ylabel='year'>],
#        [<AxesSubplot:xlabel='year', ylabel='odometer'>,
#         <AxesSubplot:xlabel='odometer', ylabel='odometer'>,
#         <AxesSubplot:xlabel='sellingprice', ylabel='odometer'>,
#         <AxesSubplot:xlabel='sale_year', ylabel='odometer'>,
#         <AxesSubplot:xlabel='age', ylabel='odometer'>],
#        [<AxesSubplot:xlabel='year', ylabel='sellingprice'>,
#         <AxesSubplot:xlabel='odometer', ylabel='sellingprice'>,
#         <AxesSubplot:xlabel='sellingprice', ylabel='sellingprice'>,
#         <AxesSubplot:xlabel='sale_year', ylabel='sellingprice'>,
#         <AxesSubplot:xlabel='age', ylabel='sellingprice'>],
#        [<AxesSubplot:xlabel='year', ylabel='sale_year'>,
# ...

# %% [markdown]
# ## отбор финального набора обучающих признаков

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433656 entries, 0 to 440235
# Data columns (total 20 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   year            433656 non-null  int64
#  1   make            433656 non-null  object
#  2   model           433656 non-null  object
#  3   trim            433656 non-null  object
#  4   body            433656 non-null  object
#  5   transmission    433656 non-null  object
#  6   vin             433656 non-null  object
#  7   state           433656 non-null  object
#  8   condition       433656 non-null  object
#  9   odometer        433656 non-null  float64
#  10  color           433656 non-null  object
#  11  interior        433656 non-null  object
#  12  seller          433656 non-null  object
#  13  sellingprice    433656 non-null  int64
#  14  saledate        433656 non-null  datetime64[ns, UTC]
#  15  vin_8           433656 non-null  object
# ...

# %%
# убираем ненужные для обучения столбцы 
ml_train = train.drop(['vin','year','saledate','sale_year','vin_8'],axis=1) #'odometer_group',,'transmission','odometer_group','trim','interior','color','make','model','body'

# %%
ml_test = test.drop(['vin','year','saledate','sale_year','vin_8'],axis=1) # убираем ненужные для обучения столбцы ,'seller' ,'transmission','odometer_group','trim','interior','color','make','model','body'

# %%
ml_train
# Out:
#           make              model       trim   body transmission state  \
# 0         ford               edge        sel    suv    automatic    md
# 1         ford             fusion         se  sedan    automatic    mo
# 2       nissan             sentra     2.0 sl  sedan    automatic    nj
# 3       hummer                 h2       base    suv    automatic    tx
# 4         ford             fusion        sel  sedan    automatic    md
# ...        ...                ...        ...    ...          ...   ...
# 440231     kia             optima  ex hybrid  sedan    automatic    ca
# 440232    mini  cooper countryman     s all4  wagon    automatic    wi
# 440233     bmw           6 series       650i  coupe    automatic    ca
# 440234     ram               2500        slt    cab    automatic    tx
# 440235  nissan              rogue         sv    suv    automatic    il
#
#        condition  odometer   color interior                       seller  \
# ...

# %%
ml_test
# Out:
#              make         model      trim   body transmission state condition  \
# 0        cadillac           cts      base  sedan    automatic    ca       3.0
# 1             gmc  savana cargo      2500    van    automatic    pa       4.0
# 2          nissan        murano         s    suv    automatic    oh       5.0
# 3       chevrolet        impala  ls fleet  sedan    automatic    fl       2.0
# 4          nissan         titan        sv    cab    automatic    tn       3.0
# ...           ...           ...       ...    ...          ...   ...       ...
# 110053       jeep      wrangler     sport    suv    automatic    ca       4.0
# 110054      lexus        is 250      base  sedan    automatic    fl       5.0
# 110055     nissan        maxima    3.5 sl  sedan    automatic    va       3.0
# 110056     nissan          370z      base  coupe       manual    tx       2.0
# 110057  chevrolet        camaro        ls  coupe    automatic    pa       4.0
#
# ...

# %%
target = ml_train['sellingprice'] # Выделяем целевой признак
features = ml_train.drop('sellingprice',axis=1) # отделяем параметры

# %%
percent_missing = features.isnull().sum() * 100 / len(features)
missing_value_df = pd.DataFrame({'column_name': features.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                    column_name  percent_missing
# make                      make              0.0
# model                    model              0.0
# trim                      trim              0.0
# body                      body              0.0
# transmission      transmission              0.0
# state                    state              0.0
# condition            condition              0.0
# odometer              odometer              0.0
# color                    color              0.0
# interior              interior              0.0
# seller                  seller              0.0
# vin_3                    vin_3              0.0
# age                        age              0.0
# odometer_group  odometer_group              0.0

# %%
percent_missing = ml_test.isnull().sum() * 100 / len(ml_test)
missing_value_df = pd.DataFrame({'column_name': ml_test.columns,
                                 'percent_missing': percent_missing})
missing_value_df
# Out:
#                    column_name  percent_missing
# make                      make              0.0
# model                    model              0.0
# trim                      trim              0.0
# body                      body              0.0
# transmission      transmission              0.0
# state                    state              0.0
# condition            condition              0.0
# odometer              odometer              0.0
# color                    color              0.0
# interior              interior              0.0
# seller                  seller              0.0
# vin_3                    vin_3              0.0
# age                        age              0.0
# odometer_group  odometer_group              0.0

# %%
# превратим в категориалные признаки condition и age
features.condition = features.condition.astype('str')
ml_test.condition = ml_test.condition.astype('str')

features.age = features.age.astype('str')
ml_test.age = ml_test.age.astype('str')

# %%
# сгруппируем столбцы на категориальные признаки и численные

numeric_features = features.select_dtypes(include='number').columns.tolist()
print(f'There are {len(numeric_features)} numerical features:', '\n')
print(numeric_features)
# Out:
# There are 1 numerical features:
#
# ['odometer']

# %%
features
# Out:
#           make              model       trim   body transmission state  \
# 0         ford               edge        sel    suv    automatic    md
# 1         ford             fusion         se  sedan    automatic    mo
# 2       nissan             sentra     2.0 sl  sedan    automatic    nj
# 3       hummer                 h2       base    suv    automatic    tx
# 4         ford             fusion        sel  sedan    automatic    md
# ...        ...                ...        ...    ...          ...   ...
# 440231     kia             optima  ex hybrid  sedan    automatic    ca
# 440232    mini  cooper countryman     s all4  wagon    automatic    wi
# 440233     bmw           6 series       650i  coupe    automatic    ca
# 440234     ram               2500        slt    cab    automatic    tx
# 440235  nissan              rogue         sv    suv    automatic    il
#
#        condition  odometer   color interior                       seller  \
# ...

# %% [markdown]
# В документации к catboost сказано, что не следует кодировать признаки перед обучением, так как там есть встроенные кодировщики, которые сильно замедлят обучение , при попытке предворительно использовать кодирование

# %%
# превращаем все не числовые признаки в категориальные
def get_categorical_indicies(X):
    cats = []
    for col in X.columns:
        if is_numeric_dtype(X[col]):
            pass
        else:
            cats.append(col)
            
    cat_indicies = []
    for col in cats:
        cat_indicies.append(X.columns.get_loc(col))
        
    return cat_indicies

def convert_cats(X):
    cats = []
    for col in X.columns:
        if is_numeric_dtype(X[col]):
            pass
        else:
            cats.append(col)
    cat_indicies = []
    for col in cats:
        X[col] = X[col].astype('category')

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433656 entries, 0 to 440235
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   make            433656 non-null  object
#  1   model           433656 non-null  object
#  2   trim            433656 non-null  object
#  3   body            433656 non-null  object
#  4   transmission    433656 non-null  object
#  5   state           433656 non-null  object
#  6   condition       433656 non-null  object
#  7   odometer        433656 non-null  float64
#  8   color           433656 non-null  object
#  9   interior        433656 non-null  object
#  10  seller          433656 non-null  object
#  11  vin_3           433656 non-null  object
#  12  age             433656 non-null  object
#  13  odometer_group  433656 non-null  object
# dtypes: float64(1), object(13)
# memory usage: 49.6+ MB

# %%
categorical_indicies = get_categorical_indicies(features)
convert_cats(features)

# %%
categorical_indicies
# Out:
# [0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12, 13]

# %%
# разделяем на валидаионную и обучающие выборки
X_train,X_valid, Y_train, Y_valid = train_test_split(features,target, test_size= 0.2 , random_state= 42 )

# %%
ml_test
# Out:
#              make         model      trim   body transmission state condition  \
# 0        cadillac           cts      base  sedan    automatic    ca       3.0
# 1             gmc  savana cargo      2500    van    automatic    pa       4.0
# 2          nissan        murano         s    suv    automatic    oh       5.0
# 3       chevrolet        impala  ls fleet  sedan    automatic    fl       2.0
# 4          nissan         titan        sv    cab    automatic    tn       3.0
# ...           ...           ...       ...    ...          ...   ...       ...
# 110053       jeep      wrangler     sport    suv    automatic    ca       4.0
# 110054      lexus        is 250      base  sedan    automatic    fl       5.0
# 110055     nissan        maxima    3.5 sl  sedan    automatic    va       3.0
# 110056     nissan          370z      base  coupe       manual    tx       2.0
# 110057  chevrolet        camaro        ls  coupe    automatic    pa       4.0
#
# ...

# %%
# трансформируем признаки в формат pool

train_dataset = Pool(X_train,Y_train, cat_features=categorical_indicies)
valid_dataset = Pool(X_valid,Y_valid, cat_features=categorical_indicies)
train_data = Pool(features,target, cat_features=categorical_indicies)
ml_test = Pool(ml_test, cat_features=categorical_indicies)

# %% [markdown]
# ## обучение модели

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


model = CatBoostRegressor(loss_function='MAPE',verbose = 5,cat_features=categorical_indicies)

# Определение диапазона гиперпараметров для поиска

param = {"iterations" : [15],
            'l2_leaf_reg': [0.0,20.76],#2-30
             'random_strength': [0.0,5],#0-5
             'depth': [16],
             'bagging_temperature': [0,30.0],#0-0.75#8.37
             'learning_rate':[ 0.3],
             'bootstrap_type':[ 'Bayesian']
            }

# Создание объекта BayesSearchCV
bayes_search = BayesSearchCV(
        estimator=model,
        search_spaces=param,
        scoring=make_scorer(mean_absolute_percentage_error, greater_is_better=False),
        n_iter=5,
        cv=3,
        random_state=42
)

# Запуск поиска гиперпараметров
bayes_search.fit(features, target)

# Вывод наилучших параметров и результатов
print("Best parameters:", bayes_search.best_params_)
print("Best score:", bayes_search.best_score_)
# Out:
# 0:	learn: 0.7605797	total: 679ms	remaining: 9.5s
# 5:	learn: 0.5837985	total: 4.15s	remaining: 6.23s
# 10:	learn: 0.4978747	total: 7.65s	remaining: 2.78s
# 14:	learn: 0.4625103	total: 10.5s	remaining: 0us
# 0:	learn: 0.7623522	total: 674ms	remaining: 9.44s
# 5:	learn: 0.5801765	total: 4.14s	remaining: 6.21s
# 10:	learn: 0.5371210	total: 7.57s	remaining: 2.75s
# 14:	learn: 0.5022912	total: 10.3s	remaining: 0us
# 0:	learn: 0.8254008	total: 687ms	remaining: 9.61s
# 5:	learn: 0.5845446	total: 4.11s	remaining: 6.16s
# 10:	learn: 0.5188520	total: 7.58s	remaining: 2.76s
# 14:	learn: 0.4905296	total: 10.4s	remaining: 0us
# 0:	learn: 0.7584640	total: 683ms	remaining: 9.55s
# 5:	learn: 0.5801634	total: 4.16s	remaining: 6.24s
# 10:	learn: 0.4983582	total: 7.65s	remaining: 2.78s
# 14:	learn: 0.4683071	total: 10.4s	remaining: 0us
# 0:	learn: 0.7971780	total: 678ms	remaining: 9.49s
# 5:	learn: 0.5882359	total: 4.2s	remaining: 6.31s
# 10:	learn: 0.5171138	total: 7.68s	remaining: 2.79s
# ...

# %%
model = CatBoostRegressor(iterations=1000,
                            l2_leaf_reg=20.76,#1,20.1
                             random_strength= 30,#1.75,#1.75,#2.07,#30,
                             depth=16,
                             bagging_temperature=28,#0.41,#8.96,# 0.36909356296798246,
                             learning_rate=0.001,#0.296,#0.24613587249332114,
                             bootstrap_type='Bayesian', loss_function='MAPE',eval_metric = 'MAPE',od_type = 'Iter' ,verbose=100)

# %%
model.fit(train_dataset,eval_set=valid_dataset, use_best_model = True)

print(f"Model is fitted: {str(model.is_fitted())}")
print(f"Model params: {model.get_params()}")
# Out:
# 0:	learn: 0.8254855	test: 0.8225729	best: 0.8225729 (0)	total: 2.38s	remaining: 39m 39s
# 100:	learn: 0.7768456	test: 0.7743982	best: 0.7743982 (100)	total: 5m 26s	remaining: 48m 22s
# 200:	learn: 0.7325396	test: 0.7306756	best: 0.7306756 (200)	total: 11m 32s	remaining: 45m 54s
# 300:	learn: 0.6945136	test: 0.6935187	best: 0.6935187 (300)	total: 17m 45s	remaining: 41m 15s
# 400:	learn: 0.6605685	test: 0.6604413	best: 0.6604413 (400)	total: 24m 9s	remaining: 36m 5s
# 500:	learn: 0.6304096	test: 0.6313550	best: 0.6313550 (500)	total: 30m 45s	remaining: 30m 38s
# 600:	learn: 0.6035830	test: 0.6058069	best: 0.6058069 (600)	total: 37m 36s	remaining: 24m 58s
# 700:	learn: 0.5793057	test: 0.5826418	best: 0.5826418 (700)	total: 44m 33s	remaining: 19m
# 800:	learn: 0.5591913	test: 0.5636857	best: 0.5636857 (800)	total: 51m 32s	remaining: 12m 48s
# 900:	learn: 0.5408567	test: 0.5465543	best: 0.5465543 (900)	total: 58m 22s	remaining: 6m 24s
# ...

# %%
print(model.get_best_score())
# Out:
# {'learn': {'MAPE': 0.5240593330358329}, 'validation': {'MAPE': 0.5308937445450991}}

# %%
pred = model.predict(ml_test)

# %% [markdown]
# ## Aнализ важности  признаков

# %%
feat_importances = model.get_feature_importance(prettified=True)
feat_importances
# Out:
#         Feature Id  Importances
# 0            state    11.870506
# 1             make    11.810825
# 2            color    11.012182
# 3             body     9.521980
# 4            vin_3     9.192236
# 5             trim     8.160364
# 6         interior     8.156446
# 7        condition     7.074041
# 8              age     6.850070
# 9         odometer     6.624710
# 10           model     5.873814
# 11  odometer_group     3.815115
# 12    transmission     0.037712
# 13          seller     0.000000

# %%
plt.figure(figsize=(12, 10))
sns.barplot(x="Importances", y="Feature Id", data=feat_importances.loc[:30, :])
plt.title('CatBoost features importance:')
# Out:
# Text(0.5, 1.0, 'CatBoost features importance:')

# %%
prediction = pd.DataFrame(test.vin)

# %%
prediction['sellingprice'] = pred

# %%
#prediction.to_csv('/kaggle/working/prediction_last.csv', index=False)

# %% [markdown]
# # Итог

# %% [markdown]
# В ходе исследования мы прошли следующие этапы:
# - загрузка и ознакомление с данными,
# - предварительная обработка,
# - разведочный анализ,
# - разработка новых синтетических признаков,
# - отбор финального набора обучающих признаков,
# - выбор и обучение моделей,
# - итоговая оценка качества предсказания модели,
# - анализ важности ее признаков.
#
# На этапе подготовки данных активно использовался vin автомобиля для идентификации его марки и модели
#
# Была предпринята попытка использовать первые 8 символов вин номера для обучения модели, но прироста метрики не произошло.
# Максимальное значение метрики при использовании максимального числа признаков, причем, если убрать признаки ,которые по результатам `get_feature_importance` показывают 0 вклад - метрика сильно падает.
# При подборе гиперпараметров использовался метод байесовского поиска.
#
# Лучший показатель модели составляет: 29%
